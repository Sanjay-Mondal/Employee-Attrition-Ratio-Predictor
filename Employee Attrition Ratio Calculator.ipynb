# %%
import pandas as pd
data=pd.read_csv('Attrition.csv')
data.head(10)
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
# 5   32        No  ...                       3                     6
# 6   59        No  ...                       0                     0
# 7   30        No  ...                       0                     0
# 8   38        No  ...                       1                     8
# 9   36        No  ...                       7                     7
#
# [10 rows x 35 columns]

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
columns=['Attrition','BusinessTravel','Department','EducationField','Gender','Over18','JobRole','MaritalStatus','OverTime']
for j in columns:
    data[j]=le.fit_transform(data[j])
data.head()
# Out:
#    Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          1  ...                        0                     5
# 1   49          0  ...                        1                     7
# 2   37          1  ...                        0                     0
# 3   33          0  ...                        3                     0
# 4   27          0  ...                        2                     2
#
# [5 rows x 35 columns]

# %%
# Exploration of data


import seaborn as sns

sns.barplot(y="Age", x="Attrition", data=data)

# %%
sns.barplot(y="Age", x="Attrition", hue="Gender", data=data)

# %%
sns.countplot(x="Gender", data=data)

# %%
data.corr()
# Out:
#                                Age  ...  YearsWithCurrManager
# Age                       1.000000  ...              0.202089
# Attrition                -0.159205  ...             -0.156199
# BusinessTravel            0.024751  ...             -0.022636
# DailyRate                 0.010661  ...             -0.026363
# Department               -0.031882  ...              0.034282
# DistanceFromHome         -0.001686  ...              0.014406
# Education                 0.208034  ...              0.069065
# EducationField           -0.040873  ...             -0.004130
# EmployeeCount                  NaN  ...                   NaN
# EmployeeNumber           -0.010145  ...             -0.009197
# EnvironmentSatisfaction   0.010146  ...             -0.004999
# Gender                   -0.036311  ...             -0.030599
# HourlyRate                0.024287  ...             -0.020123
# JobInvolvement            0.029820  ...              0.025976
# ...

# %%
sns.heatmap(data.corr())

# %%
real_x=data.drop('Attrition',axis=1).values
real_y=data['Attrition'].values

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(real_x,real_y,test_size=0.33,random_state=10)

# %%
train_x.shape
# Out:
# (984, 34)

# %%
test_x.shape
# Out:
# (486, 34)

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(train_x,train_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_y=lr.predict(test_x)

# %%
import pandas as pd


data = {'pred_y': pred_y, 'test_y': test_y}
df = pd.DataFrame(data=data)

df
# Out:
#      pred_y  test_y
# 0         0       0
# 1         0       1
# 2         0       0
# 3         0       0
# 4         0       0
# ..      ...     ...
# 481       0       0
# 482       0       0
# 483       0       0
# 484       0       0
# 485       0       0
#
# [486 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
accu1 = accuracy_score(test_y,pred_y)
accu1
# Out:
# 0.8106995884773662

# %%
# KNN classifier


from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier(n_neighbors=1)
kn.fit(train_x,train_y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
pred_k=kn.predict(test_x)


data = {'pred_y': pred_y, 'test_y': test_y}
df1 = pd.DataFrame(data=data)

df1
# Out:
#      pred_y  test_y
# 0         0       0
# 1         0       1
# 2         0       0
# 3         0       0
# 4         0       0
# ..      ...     ...
# 481       0       0
# 482       0       0
# 483       0       0
# 484       0       0
# 485       0       0
#
# [486 rows x 2 columns]

# %%
accuracy_score(test_y,pred_k)
# Out:
# 0.7448559670781894

# %% [markdown]
# WE SEE THAT WE ALTER K ACCURACY VARIES , TO AVOID THIS WE USE THE ELBOW METHOD

# %%
import numpy as np
error=[]
for j in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=j)
    knn.fit(train_x,train_y)
    pred_j=knn.predict(test_x)
    error.append(np.mean(pred_j!=test_y))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error,linestyle='dashed',markerfacecolor='red',color='blue',marker='o')

# %%
kn=KNeighborsClassifier(n_neighbors=11)
kn.fit(train_x,train_y)
pred_y=kn.predict(test_x)
accu2 = accuracy_score(test_y,pred_y)

accu2
# Out:
# 0.808641975308642

# %%
# Random Forest Classifier


from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10)
rf.fit(train_x,train_y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred_r=rf.predict(test_x)

data = {'pred_y': pred_y, 'test_y': test_y}
df2 = pd.DataFrame(data=data)

df2
# Out:
#      pred_y  test_y
# 0         0       0
# 1         0       1
# 2         0       0
# 3         0       0
# 4         0       0
# ..      ...     ...
# 481       0       0
# 482       0       0
# 483       0       0
# 484       0       0
# 485       0       0
#
# [486 rows x 2 columns]

# %%
accu3 = accuracy_score(test_y,pred_r)

accu3
# Out:
# 0.8271604938271605

# %%
# SVM 

from sklearn.svm import SVC
svm=SVC()
svm.fit(train_x,train_y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred_s=svm.predict(test_x)

data = {'pred_y': pred_y, 'test_y': test_y}
df3 = pd.DataFrame(data=data)

df3
# Out:
#      pred_y  test_y
# 0         0       0
# 1         0       1
# 2         0       0
# 3         0       0
# 4         0       0
# ..      ...     ...
# 481       0       0
# 482       0       0
# 483       0       0
# 484       0       0
# 485       0       0
#
# [486 rows x 2 columns]

# %%
accu4 = accuracy_score(test_y,pred_s)

accu4
# Out:
# 0.8106995884773662

# %%
plt.ylabel("Accuracy")
plt.xlabel("Models Deployed")
plt.title("Comparison of the models")
plt.plot(['Logistic Regression', 'KNN', 'Random Forest', 'SVM'],[accu1*100, accu2*100, accu3*100, accu4*100],linestyle='dashed',markerfacecolor='red',color='blue',marker='o')
